# %% [markdown]
# # Overlay Operations

# %%
import geopandas as gpd

chicago_comm = gpd.read_file('https://geodacenter.github.io/data-and-lab/data/Chi-CCA.zip')
chicago_comm.head()
# Out:
#    area_num_1  area_numbe        community    shape_area     shape_len  \
# 0        35.0        35.0          DOUGLAS  4.600462e+07  31027.054510
# 1        36.0        36.0          OAKLAND  1.691396e+07  19565.506153
# 2        37.0        37.0      FULLER PARK  1.991670e+07  25339.089750
# 3        38.0        38.0  GRAND BOULEVARD  4.849250e+07  28196.837157
# 4        39.0        39.0          KENWOOD  2.907174e+07  23325.167906
#
#    districtno    district  GEOID             GEOG  2000_POP  ...  KOREAN  \
# 0         7.0  South Side   35.0          Douglas   26470.0  ...   145.0
# 1         7.0  South Side   36.0          Oakland    6110.0  ...     0.0
# 2         7.0  South Side   37.0      Fuller Park    3420.0  ...     0.0
# 3         7.0  South Side   38.0  Grand Boulevard   28006.0  ...     0.0
# 4         7.0  South Side   39.0          Kenwood   18363.0  ...   124.0
#
#    OTHASIAN  OTHER_EURO  OTHUNSPEC  2000_WHITE  2000_HISP  2000_BLACK  \
# ...

# %%
chicago_comm.shape
# Out:
# (77, 217)

# %%
chicago_comm.plot()
# Out:
# <Axes: >

# %%
chicago_comm.crs
# Out:
# <Geographic 2D CRS: GEOGCS["unknown",DATUM["WGS_1984",SPHEROID["WGS 84 ...>
# Name: unknown
# Axis Info [ellipsoidal]:
# - lon[east]: Longitude (Degree)
# - lat[north]: Latitude (Degree)
# Area of Use:
# - undefined
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
chicago_sdoh = gpd.read_file('https://geodacenter.github.io/data-and-lab/data/Chi-SDOH.zip')
chicago_sdoh.head()
# Out:
#    OBJECTID    Shape_Leng    Shape_Area  TRACTCE10       geoid10  commarea  \
# 0         1  22777.477721  2.119089e+07   842400.0  1.703184e+10      44.0
# 1         2  16035.054986  8.947394e+06   840300.0  1.703184e+10      59.0
# 2         3  15186.400644  1.230614e+07   841100.0  1.703184e+10      34.0
# 3         4  10472.230301  6.731931e+06   841200.0  1.703184e+10      31.0
# 4         5  14719.443307  1.246016e+07   838200.0  1.703184e+10      28.0
#
#    ChldPvt14  EP_CROWD  EP_UNINSUR  EP_MINRTY  ...  MEANMI_14  FACHANGE  \
# 0       30.2       2.0        18.6      100.0  ...     1.0502    0.3564
# 1       38.9       4.8        25.2       85.9  ...     0.3147    0.1196
# 2       40.4       4.9        32.1       95.6  ...     0.4284    0.8937
# 3       39.5      13.2        30.9       91.5  ...     0.2220    0.0653
# 4        7.0       0.0        13.9       59.9  ...     0.9741    0.4168
#
#    PCRIMERT15  VCRIMERT15  ForclRt  EP_MUNIT  EP_GROUPQ  SchHP_Mi  BrownF_Mi  \
# ...

# %%
chicago_sdoh.shape
# Out:
# (791, 52)

# %%
chicago_sdoh.plot()
# Out:
# <Axes: >

# %%
chicago_sdoh.crs
# Out:
# <Projected CRS: EPSG:3435>
# Name: NAD83 / Illinois East (ftUS)
# Axis Info [cartesian]:
# - X[east]: Easting (US survey foot)
# - Y[north]: Northing (US survey foot)
# Area of Use:
# - name: United States (USA) - Illinois - counties of Boone; Champaign; Clark; Clay; Coles; Cook; Crawford; Cumberland; De Kalb; De Witt; Douglas; Du Page; Edgar; Edwards; Effingham; Fayette; Ford; Franklin; Gallatin; Grundy; Hamilton; Hardin; Iroquois; Jasper; Jefferson; Johnson; Kane; Kankakee; Kendall; La Salle; Lake; Lawrence; Livingston; Macon; Marion; Massac; McHenry; McLean; Moultrie; Piatt; Pope; Richland; Saline; Shelby; Vermilion; Wabash; Wayne; White; Will; Williamson.
# - bounds: (-89.27, 37.06, -87.02, 42.5)
# Coordinate Operation:
# - name: SPCS83 Illinois East zone (US survey foot)
# - method: Transverse Mercator
# Datum: North American Datum 1983
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
# Ensure both the datsets are in the same CRS
chicago_sdoh = chicago_sdoh.to_crs(chicago_comm.crs)

# %%
chicago_sdoh.crs
# Out:
# <Geographic 2D CRS: GEOGCS["unknown",DATUM["WGS_1984",SPHEROID["WGS 84 ...>
# Name: unknown
# Axis Info [ellipsoidal]:
# - lon[east]: Longitude (Degree)
# - lat[north]: Latitude (Degree)
# Area of Use:
# - undefined
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %% [markdown]
# ## Intersection

# %%
intersection = gpd.overlay(chicago_comm, chicago_sdoh, how='intersection')

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(10,10))
chicago_comm.plot(ax=ax, color='lightgrey', edgecolor='black', alpha=0.7)
intersection.plot(ax=ax, color='red', edgecolor='black', alpha=0.5)
plt.title('Intersection of Chicago Community Areas and SDOH Tracts')
plt.show()

# %% [markdown]
# ## Union

# %%
union = gpd.overlay(chicago_comm, chicago_sdoh, how='union', keep_geom_type=False)

# %%
fig, ax = plt.subplots(figsize=(10,10))
union.plot(ax=ax, color='forestgreen', edgecolor='indigo', alpha=0.5)
plt.title('Union of Chicago Community Areas and SDOH Tracts')
plt.show()

# %% [markdown]
# ## Difference

# %%
difference = gpd.overlay(chicago_comm, chicago_sdoh, how='difference', keep_geom_type=False)

# %%
fig, ax = plt.subplots(figsize=(10,10))
chicago_comm.plot(ax=ax, color='lightgrey', edgecolor='black', alpha=0.5)
difference.plot(ax=ax, color='orange', edgecolor='black', alpha=0.7)
plt.title('Difference: Chicago Community Areas not in SDOH Tracts')
plt.show()

# %%
difference2 = gpd.overlay(chicago_sdoh, chicago_comm, how='difference', keep_geom_type=False)

fig, ax = plt.subplots(figsize=(10,10))
chicago_comm.plot(ax=ax, color='lightgrey', edgecolor='black', alpha=0.5)
difference2.plot(ax=ax, color='orange', edgecolor='black', alpha=0.7)
plt.title('Difference: SDOH Tracts not in Chicago Community Areas')
plt.show()

# %% [markdown]
# ## Symmetric Difference

# %%
symmetric_difference = gpd.overlay(chicago_comm, chicago_sdoh, how='symmetric_difference', keep_geom_type=False)

# %%
fig, ax = plt.subplots(figsize=(10,10))
chicago_comm.plot(ax=ax, color='lightgrey', edgecolor='black', alpha=0.5)
symmetric_difference.plot(ax=ax, color='green', edgecolor='black', alpha=0.7)
plt.title('Symmetric Difference: Areas Unique to Each Dataset')
plt.show()

# %%
chicago_airbnb = gpd.read_file('https://geodacenter.github.io/data-and-lab/data/airbnb.zip')
chicago_airbnb = chicago_airbnb.to_crs(chicago_comm.crs)
chicago_airbnb.plot()
# Out:
# <Axes: >

# %%
symmetric_difference2 = gpd.overlay(chicago_sdoh, chicago_airbnb, how='symmetric_difference', keep_geom_type=False)

fig, ax = plt.subplots(figsize=(10,10))
chicago_comm.plot(ax=ax, color='lightgrey', edgecolor='black', alpha=0.5)
symmetric_difference2.plot(ax=ax, color='green', edgecolor='black', alpha=0.7)
plt.title('Symmetric Difference: Areas Unique to Each Dataset')
plt.show()
